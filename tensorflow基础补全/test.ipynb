# %%
students = [('Alice', 85), ('Bob', 90), ('Charlie', 78)]
sorted(students, key=lambda x: x[1], reverse=True)
# Out:
# [('Bob', 90), ('Alice', 85), ('Charlie', 78)]

# %%
students[0][1]
# Out:
# 85

# %%
count = 0.1
for i in range(19): 
    print(f'<lora:ZhongXiaoYan_XL_1013-000004:{count:.3g}>,', end='')
    count += 0.05
# Out:
# <lora:ZhongXiaoYan_XL_1013-000004:0.1>,<lora:ZhongXiaoYan_XL_1013-000004:0.15>,<lora:ZhongXiaoYan_XL_1013-000004:0.2>,<lora:ZhongXiaoYan_XL_1013-000004:0.25>,<lora:ZhongXiaoYan_XL_1013-000004:0.3>,<lora:ZhongXiaoYan_XL_1013-000004:0.35>,<lora:ZhongXiaoYan_XL_1013-000004:0.4>,<lora:ZhongXiaoYan_XL_1013-000004:0.45>,<lora:ZhongXiaoYan_XL_1013-000004:0.5>,<lora:ZhongXiaoYan_XL_1013-000004:0.55>,<lora:ZhongXiaoYan_XL_1013-000004:0.6>,<lora:ZhongXiaoYan_XL_1013-000004:0.65>,<lora:ZhongXiaoYan_XL_1013-000004:0.7>,<lora:ZhongXiaoYan_XL_1013-000004:0.75>,<lora:ZhongXiaoYan_XL_1013-000004:0.8>,<lora:ZhongXiaoYan_XL_1013-000004:0.85>,<lora:ZhongXiaoYan_XL_1013-000004:0.9>,<lora:ZhongXiaoYan_XL_1013-000004:0.95>,<lora:ZhongXiaoYan_XL_1013-000004:1>,

# %%
for i in range(10): 
    print(f'<lora:ZhongXiaoYan_XL_1013-00000{i + 1},', end='')
# Out:
# <lora:ZhongXiaoYan_XL_1013-000001,<lora:ZhongXiaoYan_XL_1013-000002,<lora:ZhongXiaoYan_XL_1013-000003,<lora:ZhongXiaoYan_XL_1013-000004,<lora:ZhongXiaoYan_XL_1013-000005,<lora:ZhongXiaoYan_XL_1013-000006,<lora:ZhongXiaoYan_XL_1013-000007,<lora:ZhongXiaoYan_XL_1013-000008,<lora:ZhongXiaoYan_XL_1013-000009,<lora:ZhongXiaoYan_XL_1013-0000010,
